# %%
import pandas as pd 
import numpy as np

# %%
column_names= ['user_id','item_id', 'rating', 'timestamp']

# %%
df= pd.read_csv('u.data', sep='\t', names= column_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles= pd.read_csv('Movie_Id_Titles')

# %%
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df= pd.merge(df, movie_titles, on='item_id')

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.set_style('white')

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
rating= pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
rating.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
rating['num_of_rating']= pd.DataFrame(df.groupby('title')['rating'].count())

# %%
rating.head()
# Out:
#                              rating  num_of_rating
# title
# 'Til There Was You (1997)  2.333333              9
# 1-900 (1994)               2.600000              5
# 101 Dalmatians (1996)      2.908257            109
# 12 Angry Men (1957)        4.344000            125
# 187 (1997)                 3.024390             41

# %%
rating['num_of_rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
rating['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating', y= 'num_of_rating', data= rating)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
movie_mat= df.pivot_table(index='user_id',columns='title', values='rating')

# %%
movie_mat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
rating.sort_values('num_of_rating', ascending=False).head()
# Out:
#                              rating  num_of_rating
# title
# Star Wars (1977)           4.359589            584
# Contact (1997)             3.803536            509
# Fargo (1996)               4.155512            508
# Return of the Jedi (1983)  4.007890            507
# Liar Liar (1997)           3.156701            485

# %%
starwars_user_rating= movie_mat['Star Wars (1977)']
liar_user_rating= movie_mat['Liar Liar (1997)']

# %%
starwars_user_rating.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
similar_to_startwars=movie_mat.corrwith(starwars_user_rating)

# %%
similar_to_liar= movie_mat.corrwith(liar_user_rating)
# Out:
# C:\Users\twish\anaconda3\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\twish\anaconda3\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_startwars= pd.DataFrame(similar_to_startwars, columns=['Correlations'])
corr_startwars.dropna(inplace=True)

# %%
corr_startwars.head()
# Out:
#                            Correlations
# title
# 'Til There Was You (1997)      0.872872
# 1-900 (1994)                  -0.645497
# 101 Dalmatians (1996)          0.211132
# 12 Angry Men (1957)            0.184289
# 187 (1997)                     0.027398

# %%
corr_startwars.sort_values('Correlations', ascending=False)
# Out:
#                             Correlations
# title
# Commandments (1997)                  1.0
# Cosi (1996)                          1.0
# No Escape (1994)                     1.0
# Stripes (1981)                       1.0
# Man of the Year (1995)               1.0
# ...                                  ...
# For Ever Mozart (1996)              -1.0
# Frankie Starlight (1995)            -1.0
# I Like It Like That (1994)          -1.0
# American Dream (1990)               -1.0
# Theodore Rex (1995)                 -1.0
#
# [1410 rows x 1 columns]

# %%
corr_startwars= corr_startwars.join(rating['num_of_rating'])

# %%
corr_startwars.head()
# Out:
#                            Correlations  num_of_rating
# title
# 'Til There Was You (1997)      0.872872              9
# 1-900 (1994)                  -0.645497              5
# 101 Dalmatians (1996)          0.211132            109
# 12 Angry Men (1957)            0.184289            125
# 187 (1997)                     0.027398             41

# %%
corr_startwars[corr_startwars['num_of_rating']>100].sort_values('Correlations', ascending=False)
# Out:
#                                                     Correlations  \
# title
# Star Wars (1977)                                        1.000000
# Empire Strikes Back, The (1980)                         0.748353
# Return of the Jedi (1983)                               0.672556
# Raiders of the Lost Ark (1981)                          0.536117
# Austin Powers: International Man of Mystery (1997)      0.377433
# ...                                                          ...
# Edge, The (1997)                                       -0.127167
# As Good As It Gets (1997)                              -0.130466
# Crash (1996)                                           -0.148507
# G.I. Jane (1997)                                       -0.176734
# First Wives Club, The (1996)                           -0.194496
#
#                                                     num_of_rating
# title
# Star Wars (1977)                                              584
# ...

# %%
corr_liar= pd.DataFrame(similar_to_liar, columns=['Correlations'])
corr_liar.dropna(inplace=True)

# %%
corr_liar.head()
# Out:
#                              Correlations
# title
# 'Til There Was You (1997)        0.118913
# 101 Dalmatians (1996)            0.469765
# 12 Angry Men (1957)              0.066272
# 187 (1997)                       0.175145
# 2 Days in the Valley (1996)      0.040739

# %%
corr_liar.sort_values('Correlations', ascending=False)
# Out:
#                                 Correlations
# title
# Bonheur, Le (1965)                       1.0
# For Ever Mozart (1996)                   1.0
# Crossfire (1947)                         1.0
# Johnny 100 Pesos (1993)                  1.0
# Moonlight and Valentino (1995)           1.0
# ...                                      ...
# Aparajito (1956)                        -1.0
# Quiet Room, The (1996)                  -1.0
# Germinal (1993)                         -1.0
# When Night Is Falling (1995)            -1.0
# Lamerica (1994)                         -1.0
#
# [1375 rows x 1 columns]

# %%
corr_liar= corr_liar.join(rating['num_of_rating'])

# %%
corr_liar.head()
# Out:
#                              Correlations  num_of_rating
# title
# 'Til There Was You (1997)        0.118913              9
# 101 Dalmatians (1996)            0.469765            109
# 12 Angry Men (1957)              0.066272            125
# 187 (1997)                       0.175145             41
# 2 Days in the Valley (1996)      0.040739             93

# %%
corr_liar[corr_liar['num_of_rating']>100].sort_values('Correlations', ascending=False)
# Out:
#                                                     Correlations  \
# title
# Liar Liar (1997)                                        1.000000
# Batman Forever (1995)                                   0.516968
# Mask, The (1994)                                        0.484650
# Down Periscope (1996)                                   0.472681
# Con Air (1997)                                          0.469828
# ...                                                          ...
# Hoop Dreams (1994)                                     -0.184503
# Ed Wood (1994)                                         -0.199481
# Dr. Strangelove or: How I Learned to Stop Worry...     -0.238092
# Welcome to the Dollhouse (1995)                        -0.254231
# Raging Bull (1980)                                     -0.308129
#
#                                                     num_of_rating
# title
# Liar Liar (1997)                                              485
# ...
